# %%
import pandas as pd
import os

#1. データの読み込み
data_path = '/Users/hayakawakazue/Downloads/data/test/33_test.csv'
data = pd.read_csv(data_path)

# ID列が含まれていることを確認
print(data.head())
print(data.dtypes)
# データの行数と列数をプリントする
print(f"データの行数: {data.shape[0]}")
print(f"データの列数: {data.shape[1]}")
# Out:
#          ID        種類  地域  市区町村コード 都道府県名  市区町村名   地区名 最寄駅：名称 最寄駅：距離（分）   間取り  \
# 0  33000189  中古マンション等 NaN    33101   岡山県  岡山市北区   伊福町     岡山        14  ２ＬＤＫ
# 1  33000471  中古マンション等 NaN    33101   岡山県  岡山市北区  大元駅前     大元         1  ３ＬＤＫ
# 2  33000579  中古マンション等 NaN    33101   岡山県  岡山市北区    表町     岡山        23   １ＤＫ
# 3  33000984  中古マンション等 NaN    33101   岡山県  岡山市北区   桑田町     岡山        13  ３ＬＤＫ
# 4  33001008  中古マンション等 NaN    33101   岡山県  岡山市北区   厚生町     岡山        18  ４ＬＤＫ
#
#    ...  今後の利用目的  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）     都市計画 建ぺい率（％） 容積率（％）  \
# 0  ...       住宅      NaN      NaN         NaN  第２種住居地域    60.0  200.0
# 1  ...       住宅      NaN      NaN         NaN     商業地域    80.0  400.0
# 2  ...       住宅      NaN      NaN         NaN     商業地域    80.0  500.0
# 3  ...       住宅      NaN      NaN         NaN     商業地域    80.0  400.0
# 4  ...       住宅      NaN      NaN         NaN     商業地域    80.0  400.0
#
#          取引時点   改装  取引の事情等
# 0  2020年第２四半期  未改装     NaN
# 1  2020年第１四半期  未改装     NaN
# 2  2020年第１四半期  未改装     NaN
# 3  2020年第１四半期  未改装     NaN
# 4  2020年第１四半期  未改装     NaN
#
# [5 rows x 27 columns]
# ID              int64
# 種類             object
# 地域            float64
# 市区町村コード         int64
# 都道府県名          object
# 市区町村名          object
# 地区名            object
# 最寄駅：名称         object
# 最寄駅：距離（分）      object
# 間取り            object
# 面積（㎡）           int64
# 土地の形状         float64
# 間口            float64
# 延床面積（㎡）       float64
# 建築年            object
# 建物の構造          object
# 用途             object
# 今後の利用目的        object
# 前面道路：方位       float64
# 前面道路：種類       float64
# 前面道路：幅員（ｍ）    float64
# 都市計画           object
# 建ぺい率（％）       float64
# 容積率（％）        float64
# 取引時点           object
# 改装             object
# 取引の事情等        float64
# dtype: object
# データの行数: 66
# データの列数: 27

# %%
#2. 不要な列を削除する

import pandas as pd
import os

#1. データの読み込み
data_path = '/Users/hayakawakazue/Downloads/data/test/33_test.csv'
data = pd.read_csv(data_path)

columns_to_drop = ['種類', '地域', '都道府県名', '市区町村名', '地区名', '最寄駅：名称', '土地の形状', 
                   '間口', '延床面積（㎡）', '用途', '今後の利用目的', '前面道路：方位', '前面道路：種類', 
                   '前面道路：幅員（ｍ）', '都市計画', '建ぺい率（％）', '容積率（％）', '改装', '取引の事情等']
data_cleaned = data.drop(columns=columns_to_drop)

print(data_cleaned.head())

# データの行数と列数をプリントする
print(f"データの行数: {data.shape[0]}")
print(f"データの列数: {data.shape[1]}")
# Out:
#          ID  市区町村コード 最寄駅：距離（分）   間取り  面積（㎡）    建築年 建物の構造        取引時点
# 0  33000189    33101        14  ２ＬＤＫ     65  平成19年    ＲＣ  2020年第２四半期
# 1  33000471    33101         1  ３ＬＤＫ     75  平成30年    ＲＣ  2020年第１四半期
# 2  33000579    33101        23   １ＤＫ     70  平成10年   ＳＲＣ  2020年第１四半期
# 3  33000984    33101        13  ３ＬＤＫ     80   令和2年    ＲＣ  2020年第１四半期
# 4  33001008    33101        18  ４ＬＤＫ     70  昭和55年   ＳＲＣ  2020年第１四半期
# データの行数: 66
# データの列数: 27

# %%
#3. 重複している行の削除

import pandas as pd
import os

#1. データの読み込み
data_path = '/Users/hayakawakazue/Downloads/data/test/33_test.csv'
data = pd.read_csv(data_path)

before_deduplication = len(data_cleaned)
data = data.drop_duplicates()
after_deduplication = len(data_cleaned)

print(f"重複行の削除: {before_deduplication - after_deduplication} 行削除されました。")

# データの行数と列数をプリントする
print(f"データの行数: {data.shape[0]}")
print(f"データの列数: {data.shape[1]}")
# Out:
# 重複行の削除: 0 行削除されました。
# データの行数: 66
# データの列数: 27

# %%
#4. 各列の欠損値の数を表示
import pandas as pd
import os

#1. データの読み込み
data_path = '/Users/hayakawakazue/Downloads/data/test/33_test.csv'
data = pd.read_csv(data_path)

print(data_cleaned.isnull().sum())

# データの行数と列数をプリントする
print(f"データの行数: {data.shape[0]}")
print(f"データの列数: {data.shape[1]}")
# Out:
# ID           0
# 市区町村コード      0
# 最寄駅：距離（分）    0
# 間取り          1
# 面積（㎡）        0
# 建築年          0
# 建物の構造        3
# 取引時点         0
# dtype: int64
# データの行数: 66
# データの列数: 27

# %%
import pandas as pd
import os

# データの読み込み
data_path = '/Users/hayakawakazue/Downloads/data/test/33_test.csv'
data = pd.read_csv(data_path)

#5. '最寄駅：距離（分）'列の欠損値を最頻値で補完
data_cleaned['最寄駅：距離（分）'].fillna(data_cleaned['最寄駅：距離（分）'].mode()[0], inplace=True)

#6. '間取り'列の欠損値を最頻値で補完
data_cleaned['間取り'].fillna(data_cleaned['間取り'].mode()[0], inplace=True)

#7. '建築年'列の欠損値を最頻値で補完
data_cleaned['建築年'].fillna(data_cleaned['建築年'].mode()[0], inplace=True)

#8. '建物の構造'列の欠損値を最頻値で補完
data_cleaned['建物の構造'].fillna(data_cleaned['建物の構造'].mode()[0], inplace=True)

#9. 欠損値の確認後に再度表示
print(data_cleaned.isnull().sum())

# データの行数と列数をプリントする
print(f"データの行数: {data.shape[0]}")
print(f"データの列数: {data.shape[1]}")
# Out:
# ID           0
# 市区町村コード      0
# 最寄駅：距離（分）    0
# 間取り          0
# 面積（㎡）        0
# 建築年          0
# 建物の構造        0
# 取引時点         0
# dtype: int64
# データの行数: 66
# データの列数: 27

# %%
#11. 各列のすべてのユニークな値を表示
import pandas as pd
import os

#1. データの読み込み
data_path = '/Users/hayakawakazue/Downloads/data/test/33_test.csv'
data = pd.read_csv(data_path)

data_cleaned = data.drop(columns=columns_to_drop)

for column in data_cleaned.columns:
    unique_values = data_cleaned[column].unique()
    print(f"列 {column} のユニークな値: {unique_values}")
    print(f"列 {column} のユニークな値の数: {len(unique_values)}")

# データの行数と列数をプリントする
print(f"データの行数: {data.shape[0]}")
print(f"データの列数: {data.shape[1]}")
# Out:
# 列 ID のユニークな値: [33000189 33000471 33000579 33000984 33001008 33001169 33001325 33001343
#  33001344 33001345 33001492 33001515 33002496 33002521 33002592 33002593
#  33002623 33002724 33002909 33002910 33002911 33002912 33002915 33002916
#  33002917 33002918 33002919 33003193 33003219 33003510 33003645 33004336
#  33004337 33004606 33004669 33004875 33004919 33004936 33004937 33006243
#  33006889 33007467 33007477 33007478 33007479 33007490 33007985 33008222
#  33008448 33008519 33008532 33008551 33008552 33008554 33009138 33009139
#  33009575 33009576 33009597 33009598 33011023 33011024 33011025 33012283
#  33013294 33013295]
# 列 ID のユニークな値の数: 66
# 列 市区町村コード のユニークな値: [33101 33102 33103 33104 33202]
# 列 市区町村コード のユニークな値の数: 5
# 列 最寄駅：距離（分） のユニークな値: ['14' '1' '23' '13' '18' '4' '26' '15' '20' '17' '6' '11' '10' '9' '5'
#  '12' '30分?60分' '19' '3' '1H30?2H' '1H?1H30' '7' '22' '16']
# 列 最寄駅：距離（分） のユニークな値の数: 24
# 列 間取り のユニークな値: ['２ＬＤＫ' '３ＬＤＫ' '１ＤＫ' '４ＬＤＫ' '１ＬＤＫ' '１Ｒ' nan '２ＬＤＫ＋Ｓ' 'オープンフロア' '３ＤＫ']
# 列 間取り のユニークな値の数: 10
# 列 面積（㎡） のユニークな値: [ 65  75  70  80  20  55  90  85  60  95 105  50  45]
# 列 面積（㎡） のユニークな値の数: 13
# 列 建築年 のユニークな値: ['平成19年' '平成30年' '平成10年' '令和2年' '昭和55年' '昭和48年' '平成11年' '昭和61年' '平成2年'
#  '昭和57年' '平成8年' '平成24年' '平成25年' '平成15年' '平成23年' '平成16年' '平成20年' '平成7年'
#  '平成28年' '昭和63年' '昭和49年' '昭和59年' '平成6年' '平成13年' '平成14年' '平成3年' '平成9年'
#  '平成18年' '平成4年' '平成26年']
# 列 建築年 のユニークな値の数: 30
# 列 建物の構造 のユニークな値: ['ＲＣ' 'ＳＲＣ' nan]
# 列 建物の構造 のユニークな値の数: 3
# 列 取引時点 のユニークな値: ['2020年第２四半期' '2020年第１四半期']
# 列 取引時点 のユニークな値の数: 2
# データの行数: 66
# データの列数: 27

# %% [markdown]
# # 上記の処理を全てまとめて行う

# %%
import pandas as pd
import os

#1. データの読み込み
data_path = '/Users/hayakawakazue/Downloads/data/test/33_test.csv'
data = pd.read_csv(data_path)

# ID列が含まれていることを確認
print(data.head())
print(data.dtypes)
# データの行数と列数をプリントする
print(f"データの行数: {data.shape[0]}")
print(f"データの列数: {data.shape[1]}")

#2. 不要な列を削除する
columns_to_drop = ['種類', '地域', '都道府県名', '市区町村名', '地区名', '最寄駅：名称', '土地の形状', 
                   '間口', '延床面積（㎡）', '用途', '今後の利用目的', '前面道路：方位', '前面道路：種類', 
                   '前面道路：幅員（ｍ）', '都市計画', '建ぺい率（％）', '容積率（％）', '改装', '取引の事情等']
data_cleaned = data.drop(columns=columns_to_drop)

print(data_cleaned.head())

#3. 重複している行の削除
before_deduplication = len(data_cleaned)
data = data.drop_duplicates()
after_deduplication = len(data_cleaned)
print(f"重複行の削除: {before_deduplication - after_deduplication} 行削除されました。")

#4. 各列の欠損値の数を表示
print(data_cleaned.isnull().sum())

#5. '最寄駅：距離（分）'列の欠損値を最頻値で補完
data_cleaned['最寄駅：距離（分）'].fillna(data_cleaned['最寄駅：距離（分）'].mode()[0], inplace=True)

#6. '間取り'列の欠損値を最頻値で補完
data_cleaned['間取り'].fillna(data_cleaned['間取り'].mode()[0], inplace=True)

#7. '建築年'列の欠損値を最頻値で補完
data_cleaned['建築年'].fillna(data_cleaned['建築年'].mode()[0], inplace=True)

#8. '建物の構造'列の欠損値を最頻値で補完
data_cleaned['建物の構造'].fillna(data_cleaned['建物の構造'].mode()[0], inplace=True)

#9. 欠損値の確認後に再度表示
print(data_cleaned.isnull().sum())

#10. データ型の確認
print(data_cleaned.dtypes)
print(f"データの行数: {data_cleaned.shape[0]}")
print(f"データの列数: {data_cleaned.shape[1]}")

#11. 各列のすべてのユニークな値を表示
for column in data_cleaned.columns:
    unique_values = data_cleaned[column].unique()
    print(f"列 {column} のユニークな値: {unique_values}")
    print(f"列 {column} のユニークな値の数: {len(unique_values)}")

# クリーニング後のデータを保存
data_cleaned_path = '/Users/hayakawakazue/Downloads/data/test/test_cleaned1/test_33_cleaned.csv'
data_cleaned.to_csv(data_cleaned_path, index=False)

# 保存されたデータを確認
print(f"データを保存しました: {data_cleaned_path}")

# データの行数と列数を確認
print(f"保存されたデータの行数: {data_cleaned.shape[0]}")
print(f"保存されたデータの列数: {data_cleaned.shape[1]}")
# Out:
#          ID        種類  地域  市区町村コード 都道府県名  市区町村名   地区名 最寄駅：名称 最寄駅：距離（分）   間取り  \
# 0  33000189  中古マンション等 NaN    33101   岡山県  岡山市北区   伊福町     岡山        14  ２ＬＤＫ
# 1  33000471  中古マンション等 NaN    33101   岡山県  岡山市北区  大元駅前     大元         1  ３ＬＤＫ
# 2  33000579  中古マンション等 NaN    33101   岡山県  岡山市北区    表町     岡山        23   １ＤＫ
# 3  33000984  中古マンション等 NaN    33101   岡山県  岡山市北区   桑田町     岡山        13  ３ＬＤＫ
# 4  33001008  中古マンション等 NaN    33101   岡山県  岡山市北区   厚生町     岡山        18  ４ＬＤＫ
#
#    ...  今後の利用目的  前面道路：方位  前面道路：種類  前面道路：幅員（ｍ）     都市計画 建ぺい率（％） 容積率（％）  \
# 0  ...       住宅      NaN      NaN         NaN  第２種住居地域    60.0  200.0
# 1  ...       住宅      NaN      NaN         NaN     商業地域    80.0  400.0
# 2  ...       住宅      NaN      NaN         NaN     商業地域    80.0  500.0
# 3  ...       住宅      NaN      NaN         NaN     商業地域    80.0  400.0
# 4  ...       住宅      NaN      NaN         NaN     商業地域    80.0  400.0
#
#          取引時点   改装  取引の事情等
# 0  2020年第２四半期  未改装     NaN
# 1  2020年第１四半期  未改装     NaN
# 2  2020年第１四半期  未改装     NaN
# 3  2020年第１四半期  未改装     NaN
# 4  2020年第１四半期  未改装     NaN
#
# [5 rows x 27 columns]
# ID              int64
# 種類             object
# 地域            float64
# 市区町村コード         int64
# 都道府県名          object
# 市区町村名          object
# 地区名            object
# 最寄駅：名称         object
# 最寄駅：距離（分）      object
# 間取り            object
# 面積（㎡）           int64
# 土地の形状         float64
# 間口            float64
# 延床面積（㎡）       float64
# 建築年            object
# 建物の構造          object
# 用途             object
# 今後の利用目的        object
# 前面道路：方位       float64
# 前面道路：種類       float64
# 前面道路：幅員（ｍ）    float64
# 都市計画           object
# 建ぺい率（％）       float64
# 容積率（％）        float64
# 取引時点           object
# 改装             object
# 取引の事情等        float64
# dtype: object
# データの行数: 66
# データの列数: 27
#          ID  市区町村コード 最寄駅：距離（分）   間取り  面積（㎡）    建築年 建物の構造        取引時点
# 0  33000189    33101        14  ２ＬＤＫ     65  平成19年    ＲＣ  2020年第２四半期
# 1  33000471    33101         1  ３ＬＤＫ     75  平成30年    ＲＣ  2020年第１四半期
# 2  33000579    33101        23   １ＤＫ     70  平成10年   ＳＲＣ  2020年第１四半期
# 3  33000984    33101        13  ３ＬＤＫ     80   令和2年    ＲＣ  2020年第１四半期
# 4  33001008    33101        18  ４ＬＤＫ     70  昭和55年   ＳＲＣ  2020年第１四半期
# 重複行の削除: 0 行削除されました。
# ID           0
# 市区町村コード      0
# 最寄駅：距離（分）    0
# 間取り          1
# 面積（㎡）        0
# 建築年          0
# 建物の構造        3
# 取引時点         0
# dtype: int64
# ID           0
# 市区町村コード      0
# 最寄駅：距離（分）    0
# 間取り          0
# 面積（㎡）        0
# 建築年          0
# 建物の構造        0
# 取引時点         0
# dtype: int64
# ID            int64
# 市区町村コード       int64
# 最寄駅：距離（分）    object
# 間取り          object
# 面積（㎡）         int64
# 建築年          object
# 建物の構造        object
# 取引時点         object
# dtype: object
# データの行数: 66
# データの列数: 8
# 列 ID のユニークな値: [33000189 33000471 33000579 33000984 33001008 33001169 33001325 33001343
#  33001344 33001345 33001492 33001515 33002496 33002521 33002592 33002593
#  33002623 33002724 33002909 33002910 33002911 33002912 33002915 33002916
#  33002917 33002918 33002919 33003193 33003219 33003510 33003645 33004336
#  33004337 33004606 33004669 33004875 33004919 33004936 33004937 33006243
#  33006889 33007467 33007477 33007478 33007479 33007490 33007985 33008222
#  33008448 33008519 33008532 33008551 33008552 33008554 33009138 33009139
#  33009575 33009576 33009597 33009598 33011023 33011024 33011025 33012283
#  33013294 33013295]
# 列 ID のユニークな値の数: 66
# 列 市区町村コード のユニークな値: [33101 33102 33103 33104 33202]
# 列 市区町村コード のユニークな値の数: 5
# 列 最寄駅：距離（分） のユニークな値: ['14' '1' '23' '13' '18' '4' '26' '15' '20' '17' '6' '11' '10' '9' '5'
#  '12' '30分?60分' '19' '3' '1H30?2H' '1H?1H30' '7' '22' '16']
# 列 最寄駅：距離（分） のユニークな値の数: 24
# 列 間取り のユニークな値: ['２ＬＤＫ' '３ＬＤＫ' '１ＤＫ' '４ＬＤＫ' '１ＬＤＫ' '１Ｒ' '２ＬＤＫ＋Ｓ' 'オープンフロア' '３ＤＫ']
# 列 間取り のユニークな値の数: 9
# 列 面積（㎡） のユニークな値: [ 65  75  70  80  20  55  90  85  60  95 105  50  45]
# 列 面積（㎡） のユニークな値の数: 13
# 列 建築年 のユニークな値: ['平成19年' '平成30年' '平成10年' '令和2年' '昭和55年' '昭和48年' '平成11年' '昭和61年' '平成2年'
#  '昭和57年' '平成8年' '平成24年' '平成25年' '平成15年' '平成23年' '平成16年' '平成20年' '平成7年'
#  '平成28年' '昭和63年' '昭和49年' '昭和59年' '平成6年' '平成13年' '平成14年' '平成3年' '平成9年'
#  '平成18年' '平成4年' '平成26年']
# 列 建築年 のユニークな値の数: 30
# 列 建物の構造 のユニークな値: ['ＲＣ' 'ＳＲＣ']
# 列 建物の構造 のユニークな値の数: 2
# 列 取引時点 のユニークな値: ['2020年第２四半期' '2020年第１四半期']
# 列 取引時点 のユニークな値の数: 2
# データを保存しました: /Users/hayakawakazue/Downloads/data/test/test_cleaned1/test_33_cleaned.csv
# 保存されたデータの行数: 66
# 保存されたデータの列数: 8
